# %% [markdown]
# <a href="https://colab.research.google.com/github/brem-21/Titanic/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration and Visualization

# %% [markdown]
# *   Load Titanic Dataset
# *   Analyze key statistics for each feature
# *   Vusualize relationships among features

# %%
# importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
# Loding the data and print first 5 rows
titanic_data = pd.read_csv('https://raw.githubusercontent.com/brem-21/Titanic/refs/heads/main/Data/train.csv')
titanic_data.head()
# Out:
#    PassengerId  Pclass                                         Name     Sex  \
# 0          693       3                                 Lam, Mr. Ali    male
# 1          482       2             Frost, Mr. Anthony Wood "Archie"    male
# 2          528       1                           Farthing, Mr. John    male
# 3          856       3                   Aks, Mrs. Sam (Leah Rosen)  female
# 4          802       2  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female
#
#     Age  SibSp  Parch      Ticket      Fare Cabin Embarked  Survived
# 0   NaN      0      0        1601   56.4958   NaN        S         1
# 1   NaN      0      0      239854    0.0000   NaN        S         0
# 2   NaN      0      0    PC 17483  221.7792   C95        S         0
# 3  18.0      0      1      392091    9.3500   NaN        S         1
# 4  31.0      1      1  C.A. 31921   26.2500   NaN        S         1

# %%
# Information of the data
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Pclass       712 non-null    int64
#  2   Name         712 non-null    object
#  3   Sex          712 non-null    object
#  4   Age          575 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Ticket       712 non-null    object
#  8   Fare         712 non-null    float64
#  9   Cabin        160 non-null    object
#  10  Embarked     710 non-null    object
#  11  Survived     712 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.9+ KB

# %%
# Key statistics for each feature
titanic_data.describe(include='all')
# Out:
#         PassengerId      Pclass          Name   Sex         Age       SibSp  \
# count    712.000000  712.000000           712   712  575.000000  712.000000
# unique          NaN         NaN           712     2         NaN         NaN
# top             NaN         NaN  Lam, Mr. Ali  male         NaN         NaN
# freq            NaN         NaN             1   459         NaN         NaN
# mean     444.405899    2.308989           NaN   NaN   29.807687    0.492978
# std      257.465527    0.833563           NaN   NaN   14.485211    1.060720
# min        1.000000    1.000000           NaN   NaN    0.420000    0.000000
# 25%      222.750000    2.000000           NaN   NaN   21.000000    0.000000
# 50%      439.500000    3.000000           NaN   NaN   28.500000    0.000000
# 75%      667.250000    3.000000           NaN   NaN   39.000000    1.000000
# max      891.000000    3.000000           NaN   NaN   80.000000    8.000000
#
# ...

# %%
# Converting the columns to objects for a clearer overview and Easy Analysis
titanic_data['Survived'] = titanic_data['Survived'].map({0: 'No', 1: 'Yes'})

titanic_data['Pclass'] = titanic_data['Pclass'].map({1: '1st', 2: '2nd', 3: '3rd'})

titanic_data['Embarked'] = titanic_data['Embarked'].map({'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'})

# %%
plt.figure(figsize=(8, 6))
plt.hist(titanic_data['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
_ = plt.ylabel('Frequency')

# %%
# Histograms
titanic_data.hist(figsize=(12, 8), bins=20)
plt.tight_layout()
plt.show()

# Boxplots
numerical_cols = titanic_data.select_dtypes(include=np.number).columns
for col in numerical_cols:
    sns.boxplot(y=titanic_data[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# Viewing the transformed data
titanic_data.head()
# Out:
#    PassengerId Pclass                                         Name     Sex  \
# 0          693    3rd                                 Lam, Mr. Ali    male
# 1          482    2nd             Frost, Mr. Anthony Wood "Archie"    male
# 2          528    1st                           Farthing, Mr. John    male
# 3          856    3rd                   Aks, Mrs. Sam (Leah Rosen)  female
# 4          802    2nd  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female
#
#     Age  SibSp  Parch      Ticket      Fare Cabin     Embarked Survived
# 0   NaN      0      0        1601   56.4958   NaN  Southampton      Yes
# 1   NaN      0      0      239854    0.0000   NaN  Southampton       No
# 2   NaN      0      0    PC 17483  221.7792   C95  Southampton       No
# 3  18.0      0      1      392091    9.3500   NaN  Southampton      Yes
# 4  31.0      1      1  C.A. 31921   26.2500   NaN  Southampton      Yes

# %%
# Counts of survival by Gender
pd.DataFrame(titanic_data.groupby('Sex')['Survived'].value_counts())
# Out:
#                  count
# Sex    Survived
# female Yes         188
#        No           65
# male   No          374
#        Yes          85

# %%
# Count plot to visualize survival rate among Gender
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['Sex'], hue=titanic_data['Survived'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'Survival By Gender')  # Set the title for each plot
plt.xlabel('Gender')  # Label for x-axis
plt.ylabel('Number of Survival')  # Label for y-axis
plt.show()

# %%
# Counts of survival by ticket class
pd.DataFrame(titanic_data.groupby('Pclass')['Survived'].value_counts())
# Out:
#                  count
# Pclass Survived
# 1st    Yes         111
#        No           60
# 2nd    No           83
#        Yes          67
# 3rd    No          296
#        Yes          95

# %%
# Count plot to visualize survival rate among age
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['Pclass'], hue=titanic_data['Survived'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'Survival By Ticket Class')  # Set the title for each plot
plt.xlabel('Ticket Class')  # Label for x-axis
plt.ylabel('Number of Survival')  # Label for y-axis
plt.show()

# %%
# Counts of survival by port of Embarkation
pd.DataFrame(titanic_data.groupby('Embarked')['Survived'].value_counts())
# Out:
#                       count
# Embarked    Survived
# Cherbourg   Yes          78
#             No           61
# Queenstown  No           31
#             Yes          24
# Southampton No          347
#             Yes         169

# %%
# Count plot to visualize survival rate among Gender
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['Embarked'], hue=titanic_data['Survived'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'Survival By Port of Embarkation')  # Set the title for each plot
plt.xlabel('Port of Embarkation')  # Label for x-axis
plt.ylabel('Number of Survival')  # Label for y-axis
plt.show()

# %%
# Counts of port of embarkation by ticket class
pd.DataFrame(titanic_data.groupby('Embarked')['Pclass'].value_counts())
# Out:
#                     count
# Embarked    Pclass
# Cherbourg   1st        74
#             3rd        53
#             2nd        12
# Queenstown  3rd        52
#             2nd         2
#             1st         1
# Southampton 3rd       286
#             2nd       136
#             1st        94

# %%
# Count plot to visualize survival rate among Gender
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['Embarked'], hue=titanic_data['Pclass'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'PORT OF EMBARKATION BY TICKET CLASS')  # Set the title for each plot
plt.xlabel('Port of Embarkation')  # Label for x-axis
plt.ylabel('Count of Passengers')  # Label for y-axis
plt.show()

# %%
# Counts of port of embarkation by ticket class
pd.DataFrame(titanic_data.groupby('SibSp')['Survived'].value_counts())
# Out:
#                 count
# SibSp Survived
# 0     No          324
#       Yes         170
# 1     Yes          88
#       No           76
# 2     Yes          11
#       No           10
# 3     No            9
#       Yes           1
# 4     No           12
#       Yes           3
# 5     No            3
# 8     No            5

# %%
# Count plot to visualize survival rate among Siblings and Spouses
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['SibSp'], hue=titanic_data['Survived'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'SURVIVAL RATE AMONG SIBLINGS AND SPOUSES')  # Set the title for each plot
plt.xlabel('Siblings and Spouses')  # Label for x-axis
plt.ylabel('Count of Siblings and spouses')  # Label for y-axis
plt.show()

# %%
# Counts of port of embarkation by ticket class
pd.DataFrame(titanic_data.groupby('Parch')['Survived'].value_counts())
# Out:
#                 count
# Parch Survived
# 0     No          357
#       Yes         185
# 1     Yes          51
#       No           43
# 2     Yes          33
#       No           28
# 3     Yes           3
#       No            2
# 4     No            4
# 5     No            4
#       Yes           1
# 6     No            1

# %%
# Count plot to visualize survival rate among Gender
plt.figure(figsize=(8, 6))  # Set the figure size for the plot
sns.countplot(data=titanic_data, x=titanic_data['Parch'], hue=titanic_data['Survived'], palette='coolwarm')  # Bar plot with Survived  as hue
plt.title(f'SURVIVAL RATE AMONG PARENTS AND CHILDREN ABOARD')  # Set the title for each plot
plt.xlabel('Parents and Children')  # Label for x-axis
plt.ylabel('Count of Parents and children')  # Label for y-axis
plt.show()

# %%
pd.DataFrame(titanic_data['Cabin'].unique())
# Out:
#                0
# 0            NaN
# 1            C95
# 2            A26
# 3            C78
# 4            D15
# ..           ...
# 123  B51 B53 B55
# 124         C148
# 125          C49
# 126          C86
# 127          E63
#
# [128 rows x 1 columns]

# %% [markdown]
# ## Data Cleaning and Preprocessing
#
#
# *   Handle missing vlaues
# *   Encode Categorical variables
# *   Normalize/Scale to numerical features
# *   Split the dataset into training and validation sets

# %%
# Checking for missing values
pd.DataFrame(titanic_data.isnull().sum())
# Out:
#                0
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age          137
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        552
# Embarked       2
# Survived       0

# %%
# Handling missing values for Embarked column
titanic_data['Embarked'] = titanic_data['Embarked'].fillna(titanic_data['Embarked'].mode()[0])

# Handling missing values for Age column
titanic_data['Age'] = titanic_data['Age'].fillna(titanic_data['Age'].mean())

# Handling missing values for Cabin column
titanic_data['Cabin'] = titanic_data['Cabin'].fillna(titanic_data['Cabin'].mode()[0])

# %%
# rechecking for missing values
pd.DataFrame(titanic_data.isnull().sum())
# Out:
#              0
# PassengerId  0
# Pclass       0
# Name         0
# Sex          0
# Age          0
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# Cabin        0
# Embarked     0
# Survived     0

# %%
# checking for columns for unique values
pd.DataFrame(titanic_data.nunique())
# Out:
#                0
# PassengerId  712
# Pclass         3
# Name         712
# Sex            2
# Age           86
# SibSp          7
# Parch          7
# Ticket       571
# Fare         226
# Cabin        127
# Embarked       3
# Survived       2

# %%
titanic_data.Parch.unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
titanic_data.SibSp.unique()
# Out:
# array([0, 1, 8, 3, 4, 2, 5])

# %%
titanic_data.Embarked.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
titanic_data.Survived.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
titanic_data.Cabin.unique()
# Out:
# array(['G6', 'C95', 'A26', 'C78', 'D15', 'E49', 'C52', 'C104', 'A5',
#        'F G73', 'E44', 'B96 B98', 'D30', 'C45', 'C70', 'B57 B59 B63 B66',
#        'B80', 'F E69', 'C106', 'E8', 'D9', 'E68', 'D17', 'B58 B60',
#        'C125', 'B18', 'C83', 'B3', 'F33', 'C92', 'E121', 'B22', 'E33',
#        'C23 C25 C27', 'E67', 'B35', 'C85', 'F2', 'E12', 'A14', 'B86',
#        'A10', 'D45', 'C47', 'D33', 'D6', 'C91', 'C62 C64', 'C65', 'B101',
#        'A7', 'A31', 'D49', 'D11', 'D35', 'E101', 'B69', 'B102', 'C7',
#        'C2', 'C124', 'C82', 'B4', 'A34', 'D26', 'C110', 'A19', 'B42',
#        'A16', 'B78', 'B94', 'B50', 'E34', 'C99', 'C118', 'D10 D12', 'E46',
#        'B39', 'B19', 'C68', 'B37', 'A20', 'B30', 'A24', 'D56', 'E58',
#        'E25', 'E36', 'F4', 'T', 'D', 'C126', 'C32', 'C22 C26', 'E17',
#        'C90', 'D19', 'E24', 'D47', 'E38', 'B82 B84', 'B49', 'E50', 'B28',
#        'C93', 'F G63', 'D21', 'E77', 'C46', 'E10', 'D20', 'A32', 'C123',
# ...

# %%
# Checking the data type of each column
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Pclass       712 non-null    object
#  2   Name         712 non-null    object
#  3   Sex          712 non-null    object
#  4   Age          712 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Ticket       712 non-null    object
#  8   Fare         712 non-null    float64
#  9   Cabin        712 non-null    object
#  10  Embarked     712 non-null    object
#  11  Survived     712 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 66.9+ KB

# %%
# Checking the unique values for the Ticket column
titanic_data.Ticket.unique()
# Out:
# array(['1601', '239854', 'PC 17483', '392091', 'C.A. 31921', '8475',
#        'PC 17757', '367228', '345763', '13213', '4137', 'CA. 2343',
#        '113792', 'A/4. 39886', '19928', 'A/5. 13032', '362316', 'C 7075',
#        '4133', 'A/5. 3336', '11813', 'PC 17585', 'SW/PP 751', '349233',
#        '223596', '349204', '4579', 'PC 17756', 'SOTON/OQ 392089',
#        '349218', 'C.A. 24579', '110564', 'S.O.P. 1166', '237565',
#        'A/5 3540', '229236', '250648', '248738', '382649', 'C.A. 29178',
#        '2671', '234604', '312991', '350046', '113786', 'PC 17754',
#        'STON/O 2. 3101293', '348124', '370365', '7553', '13507', '347088',
#        '113760', '113773', '113798', 'C 7076', 'A/4 45380', 'P/PP 3381',
#        '231919', 'LINE', '239855', '347054', 'Fa 265302',
#        'STON/O2. 3101279', '347082', 'W/C 14208', '2672', '3101295',
#        '113789', '17421', '36209', '365226', 'CA. 2314', 'A/5 3594',
#        'PC 17608', 'PC 17569', 'SC/Paris 2123', '250644', '219533',
# ...

# %%
titanic_data.head()
# Out:
#    PassengerId Pclass                                         Name     Sex  \
# 0          693    3rd                                 Lam, Mr. Ali    male
# 1          482    2nd             Frost, Mr. Anthony Wood "Archie"    male
# 2          528    1st                           Farthing, Mr. John    male
# 3          856    3rd                   Aks, Mrs. Sam (Leah Rosen)  female
# 4          802    2nd  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female
#
#          Age  SibSp  Parch      Ticket      Fare Cabin     Embarked Survived
# 0  29.807687      0      0        1601   56.4958    G6  Southampton      Yes
# 1  29.807687      0      0      239854    0.0000    G6  Southampton       No
# 2  29.807687      0      0    PC 17483  221.7792   C95  Southampton       No
# 3  18.000000      0      1      392091    9.3500    G6  Southampton      Yes
# 4  31.000000      1      1  C.A. 31921   26.2500    G6  Southampton      Yes

# %%
# Importing the encoder to encode the binary categorical varibales
from sklearn.preprocessing import LabelEncoder, StandardScaler

columns_to_encode = ['Pclass', 'Sex', 'Embarked', 'Survived']
label_encoder = LabelEncoder()

for column in columns_to_encode:
    titanic_data[column] = label_encoder.fit_transform(titanic_data[column])

# %%
# Printing some few rows to confirm the transformation
titanic_data.head()
# Out:
#    PassengerId  Pclass                                         Name  Sex  \
# 0          693       2                                 Lam, Mr. Ali    1
# 1          482       1             Frost, Mr. Anthony Wood "Archie"    1
# 2          528       0                           Farthing, Mr. John    1
# 3          856       2                   Aks, Mrs. Sam (Leah Rosen)    0
# 4          802       1  Collyer, Mrs. Harvey (Charlotte Annie Tate)    0
#
#          Age  SibSp  Parch      Ticket      Fare Cabin  Embarked  Survived
# 0  29.807687      0      0        1601   56.4958    G6         2         1
# 1  29.807687      0      0      239854    0.0000    G6         2         0
# 2  29.807687      0      0    PC 17483  221.7792   C95         2         0
# 3  18.000000      0      1      392091    9.3500    G6         2         1
# 4  31.000000      1      1  C.A. 31921   26.2500    G6         2         1

# %%
# Removing Irrelevant columns
titanic_data = titanic_data.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

# %%
# Confirming the dropping
titanic_data.head()
# Out:
#    Pclass  Sex        Age  SibSp  Parch      Fare  Embarked  Survived
# 0       2    1  29.807687      0      0   56.4958         2         1
# 1       1    1  29.807687      0      0    0.0000         2         0
# 2       0    1  29.807687      0      0  221.7792         2         0
# 3       2    0  18.000000      0      1    9.3500         2         1
# 4       1    0  31.000000      1      1   26.2500         2         1

# %%
features = titanic_data.drop('Survived', axis=1)

# %%
# Scaling the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)

# Optionally, convert the scaled features back into a DataFrame for easier interpretation
X_scaled_df = pd.DataFrame(X_scaled, columns=features.columns)

# Check the scaled data
print("Scaled features:\n", X_scaled_df.head())
# Out:
# Scaled features:
#       Pclass       Sex           Age     SibSp     Parch      Fare  Embarked
# 0  0.829568  0.742427 -5.463229e-16 -0.465084 -0.466183  0.513812  0.584892
# 1 -0.370945  0.742427 -5.463229e-16 -0.465084 -0.466183 -0.662563  0.584892
# 2 -1.571457  0.742427 -5.463229e-16 -0.465084 -0.466183  3.955399  0.584892
# 3  0.829568 -1.346933 -9.078708e-01 -0.465084  0.727782 -0.467874  0.584892
# 4 -0.370945 -1.346933  9.167471e-02  0.478335  0.727782 -0.115977  0.584892

# %%
# Splitting the data into target and features
X = features
y = titanic_data['Survived']

# %% [markdown]
# ## Feature Engineering
#
#
# *   Feature Selection using Correlation Analysis, importance Score

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

selector_mutual_info = SelectKBest(score_func=mutual_info_classif, k=4)
X_selected_mutual_info = selector_mutual_info.fit_transform(X, y)
selected_features_mutual_info = X.columns[selector_mutual_info.get_support()]
print(f"Selected features using mutual_info_classif: {selected_features_mutual_info}")
print("Feature scores (mutual_info_classif):", selector_mutual_info.scores_)
# Out:
# Selected features using mutual_info_classif: Index(['Pclass', 'Sex', 'Age', 'Fare'], dtype='object')
# Feature scores (mutual_info_classif): [0.0599964  0.15411239 0.03799519 0.         0.         0.15636802
#  0.00509176]

# %%
titanic_data.corr()
# Out:
#             Pclass       Sex       Age     SibSp     Parch      Fare  \
# Pclass    1.000000  0.145052 -0.315102  0.097900  0.040467 -0.556540
# Sex       0.145052  1.000000  0.078427 -0.100430 -0.256527 -0.206986
# Age      -0.315102  0.078427  1.000000 -0.237664 -0.167355  0.101019
# SibSp     0.097900 -0.100430 -0.237664  1.000000  0.392269  0.127011
# Parch     0.040467 -0.256527 -0.167355  0.392269  1.000000  0.177235
# Fare     -0.556540 -0.206986  0.101019  0.127011  0.177235  1.000000
# Embarked  0.197985  0.127243 -0.033954  0.061579  0.046178 -0.262451
# Survived -0.348007 -0.549171 -0.076462 -0.026115  0.084178  0.275499
#
#           Embarked  Survived
# Pclass    0.197985 -0.348007
# Sex       0.127243 -0.549171
# Age      -0.033954 -0.076462
# SibSp     0.061579 -0.026115
# Parch     0.046178  0.084178
# Fare     -0.262451  0.275499
# Embarked  1.000000 -0.188997
# Survived -0.188997  1.000000

# %%
# Correlation Analysis of the data
plt.figure(figsize=(10, 6))
sns.heatmap(titanic_data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X_selected_mutual_info, y, test_size=0.2, random_state=42)

# Printing the shapes of the training and test sets
print(f"X train shape: {X_train.shape}")
print(f"y train shape: {y_train.shape}")
print(f"X test shape: {X_test.shape}")
print(f"y test shape: {y_test.shape}")
# Out:
# X train shape: (569, 4)
# y train shape: (569,)
# X test shape: (143, 4)
# y test shape: (143,)

# %% [markdown]
# ## Model Selection and Training
#
#
# *   Metrics for evalution

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.neighbors import KNeighborsClassifier


# Define models
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier': SVC(probability=True),
    'Gradient Boosting': GradientBoostingClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=3)


}

# Define scoring metrics
scoring_metrics = {
    'accuracy': accuracy_score,
    'precision': precision_score,
    'recall': recall_score,
    'f1': f1_score,
    'roc_auc': roc_auc_score
}

# Initialize a list to store the results
# Prepare results storage
results = []

# Train and evaluate models
for model_name, model in models.items():
    print(f"Evaluating {model_name}...")

    # Fit the model
    model.fit(X_train, y_train)

    # Get predictions
    y_pred = model.predict(X_test)

    # Evaluate performance using different metrics
    metrics_result = {'Model': model_name}
    metrics_result['accuracy'] = round(accuracy_score(y_test, y_pred),2)
    metrics_result['precision'] = round(precision_score(y_test, y_pred),2)
    metrics_result['recall'] = round(recall_score(y_test, y_pred),2)
    metrics_result['f1'] = round(f1_score(y_test, y_pred),2)
    metrics_result['roc_auc'] = round(roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]) if hasattr(model, 'predict_proba') else None, 2)

    # Append results
    results.append(metrics_result)

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Display results
print("\nModel performance comparison:")
print(results_df)
# Out:
# Evaluating Logistic Regression...
# Evaluating Decision Tree...
# Evaluating Random Forest...
# Evaluating Support Vector Classifier...
# Evaluating Gradient Boosting...
# Evaluating K-Nearest Neighbors...
#
# Model performance comparison:
#                        Model  accuracy  precision  recall    f1  roc_auc
# 0        Logistic Regression      0.75       0.73    0.63  0.67     0.81
# 1              Decision Tree      0.76       0.73    0.68  0.70     0.74
# 2              Random Forest      0.81       0.80    0.73  0.76     0.86
# 3  Support Vector Classifier      0.66       0.75    0.25  0.38     0.74
# 4          Gradient Boosting      0.83       0.86    0.71  0.78     0.87
# 5        K-Nearest Neighbors      0.73       0.72    0.58  0.64     0.73

# %% [markdown]
# ## Model Optimization
#
# Hyperparameter tuning using GridSearchCV

# %%
# Define hyperparameters for GridSearchCV
param_grids = {
    'Logistic Regression': {
        'C': [0.1, 1, 10],
        'penalty': ['l2'],
        'solver': ['lbfgs', 'liblinear']
    },
    'Decision Tree': {
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 10, 20],
        'min_samples_leaf': [1, 5, 10]
    },
    'Random Forest': {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 10],
        'min_samples_leaf': [1, 5]
    },
    'Support Vector Classifier': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    },
    'Gradient Boosting': {
        'n_estimators': [100, 200],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [3, 5, 7]
    },
    'K-Nearest Neighbors': {
        'n_neighbors': [3, 5, 11],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    }
}

# Define scoring metrics
scoring_metrics = {
    'accuracy': accuracy_score,
    'precision': precision_score,
    'recall': recall_score,
    'f1': f1_score,
    'roc_auc': roc_auc_score
}

# %%
results = []

# Perform hyperparameter tuning using GridSearchCV
for model_name, model in models.items():
    print(f"Performing hyperparameter tuning for {model_name}...")

    # Select the parameter grid for the current model
    param_grid = param_grids[model_name]

    # Use GridSearchCV for exhaustive search
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Get the best model from GridSearchCV
    best_model = grid_search.best_estimator_
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")

    # Evaluate the best model using different metrics
    metrics_result = {'Model': model_name}
    y_pred = best_model.predict(X_test)

    metrics_result['accuracy'] = round(accuracy_score(y_test, y_pred), 2)
    metrics_result['precision'] = round(precision_score(y_test, y_pred),2)
    metrics_result['recall'] = round(recall_score(y_test, y_pred),2)
    metrics_result['f1'] = round(f1_score(y_test, y_pred),2)
    metrics_result['roc_auc'] = round(roc_auc_score(y_test, best_model.predict_proba(X_test)[:, 1]) if hasattr(best_model, 'predict_proba') else None,2)

    # Append results
    results.append(metrics_result)

# Convert the results into a DataFrame for easy comparison
results_df = pd.DataFrame(results)

# Display results
print("\nOptimized Model Performance Comparison:")
print(results_df)
# Out:
# Performing hyperparameter tuning for Logistic Regression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for Logistic Regression: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Performing hyperparameter tuning for Decision Tree...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters for Decision Tree: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# Performing hyperparameter tuning for Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best parameters for Random Forest: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Performing hyperparameter tuning for Support Vector Classifier...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters for Support Vector Classifier: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Performing hyperparameter tuning for Gradient Boosting...
# ...

# %%
# Create a DataFrame to hold the feature names and scores for plotting
feature_scores_df = pd.DataFrame({
    'Feature': X.columns,
    'Score': selector_mutual_info.scores_
})

# Sort the features by their scores in descending order
feature_scores_df = feature_scores_df.sort_values(by='Score', ascending=False)

# Create a barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='Score', y='Feature', data=feature_scores_df, palette='viridis')
plt.title('Feature Scores Using Mutual Information')
plt.xlabel('Score')
plt.ylabel('Feature')
plt.show()
# Out:
# <ipython-input-48-be401ae6cd1a>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score', y='Feature', data=feature_scores_df, palette='viridis')

# %%
import numpy as np

# Assume `best_model` is a tree-based model
if hasattr(best_model, 'feature_importances_'):
    feature_importance = best_model.feature_importances_
    feature_names = X_train.columns  # Replace with your feature names

    # Create a DataFrame for better visualization
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': feature_importance
    }).sort_values(by='Importance', ascending=False)

    # Plot the feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    plt.gca().invert_yaxis()  # Reverse the order for better readability
    plt.title('Feature Importance')
    plt.xlabel('Importance')
    plt.show()
